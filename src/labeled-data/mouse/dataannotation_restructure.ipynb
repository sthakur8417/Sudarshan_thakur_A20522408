# %%
import pandas as pd

# %%
# !ls
# Out:
# A_male_in_a_new_cage_face_view_3_2022-08-10_15-39-01_1078.png
# A_male_in_a_new_cage_face_view_3_2022-08-10_15-39-01_1105.png
# A_male_in_a_new_cage_face_view_3_2022-08-10_15-39-01_196.png
# A_male_in_a_new_cage_face_view_3_2022-08-10_15-39-01_338.png
# A_male_in_a_new_cage_face_view_3_2022-08-10_15-39-01_500.png
# A_male_in_a_new_cage_face_view_3_2022-08-10_15-39-01_518.png
# A_male_in_a_new_cage_face_view_3_2022-08-10_15-39-01_583.png
# A_male_in_a_new_cage_face_view_3_2022-08-10_15-39-01_593.png
# A_male_in_a_new_cage_face_view_3_2022-08-10_15-39-01_673.png
# A_male_in_a_new_cage_face_view_3_2022-08-10_15-39-01_849.png
# A_male_in_a_new_cage_face_view_3_2022-08-10_15-39-01_951.png
# A_male_in_a_new_cage_side_view_4_2022-08-10_15-39-03_1047.png
# A_male_in_a_new_cage_side_view_4_2022-08-10_15-39-03_1107.png
# A_male_in_a_new_cage_side_view_4_2022-08-10_15-39-03_168.png
# A_male_in_a_new_cage_side_view_4_2022-08-10_15-39-03_321.png
# ...

# %%
data=pd.read_csv('CollectedData_annotation.csv')

# %%
data.columns
# Out:
# Index(['scorer', 'Unnamed: 1', 'annotation', 'annotation.1', 'annotation.2',
#        'annotation.3', 'annotation.4', 'annotation.5', 'annotation.6',
#        'annotation.7', 'annotation.8', 'annotation.9', 'annotation.10',
#        'annotation.11', 'annotation.12', 'annotation.13', 'annotation.14',
#        'annotation.15', 'annotation.16', 'annotation.17', 'annotation.18',
#        'annotation.19', 'annotation.20', 'annotation.21', 'annotation.22',
#        'annotation.23', 'annotation.24', 'annotation.25', 'annotation.26',
#        'annotation.27', 'annotation.28', 'annotation.29', 'annotation.30',
#        'annotation.31', 'annotation.32', 'annotation.33', 'annotation.34',
#        'annotation.35'],
#       dtype='object')

# %%
data['scorer'][3:]=data['scorer'][3:]+'/mouse/'+data['Unnamed: 1'][3:]

# %%
data.drop(['Unnamed: 1'],axis=1,inplace=True)

# %%
data.to_csv('mouse_annotation.csv')

# %%
data.head(5)
# Out:
#                                               scorer   annotation  \
# 0                                        individuals       mouse1
# 1                                          bodyparts      topleft
# 2                                             coords            x
# 3  labeled-data/mouse/A_male_in_a_new_cage_face_v...  323.8034481
# 4  labeled-data/mouse/A_male_in_a_new_cage_face_v...  170.4444374
#
#   annotation.1 annotation.2 annotation.3 annotation.4 annotation.5  \
# 0       mouse1       mouse1       mouse1       mouse1       mouse1
# 1      topleft    rightdown    rightdown         nose         nose
# 2            y            x            y            x            y
# 3  93.03994521  420.0440517  235.4447409  397.3531777  111.8185996
# 4  185.3683292  345.7118782  341.0746717          NaN          NaN
#
#   annotation.6 annotation.7 annotation.8  ... annotation.26 annotation.27  \
# 0       mouse1       mouse1       mouse1  ...        mouse2        mouse2
# ...
